# %%
import pandas as pd
import numpy as np
import seaborn as sns
df = pd.read_csv('Downloads/healthcare-dataset-stroke-data.csv')

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.shape
# Out:
# (5110, 12)

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df['bmi'].fillna(df['bmi'].mode()[0],inplace = True)

# %%
df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
sns.countplot('gender', data = df)
# Out:
# C:\Users\Vyshnavi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot('work_type', data = df)
# Out:
# C:\Users\Vyshnavi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='work_type', ylabel='count'>

# %%
sns.countplot('smoking_status', data = df)
# Out:
# C:\Users\Vyshnavi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoking_status', ylabel='count'>

# %%
#df['heart_disease'].value_counts()

# %%
#sns.countplot('heart_disease', data = df)

# %%
#sns.countplot('stroke', data = df)

# %%
#sns.countplot('gender', hue ='stroke', data = df)

# %% [markdown]
# # Data transformation

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  28.7     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.replace({'gender' : {'Male' : 0 , 'Female' : 1 , 'Other' : 2}}, inplace = True)

# %%
df.replace({'smoking_status' : {'never smoked' : 0 ,'Unknown' : 1, 'formerly smoked' : 2 , 'smokes' : 3}}, inplace = True)

# %%
df.replace({'Residence_type' : {'Urban' : 0 , 'Rural' : 1}}, inplace = True)

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046       0  67.0             0              1          Yes
# 1  51676       1  61.0             0              0          Yes
# 2  31112       0  80.0             0              1          Yes
# 3  60182       1  49.0             0              0          Yes
# 4   1665       1  79.0             1              0          Yes
#
#        work_type  Residence_type  avg_glucose_level   bmi  smoking_status  \
# 0        Private               0             228.69  36.6               2
# 1  Self-employed               1             202.21  28.7               0
# 2        Private               1             105.92  32.5               0
# 3        Private               0             171.23  34.4               3
# 4  Self-employed               1             174.12  24.0               0
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                          id    gender       age  hypertension  heart_disease  \
# id                 1.000000 -0.001406  0.003538      0.003550      -0.001296
# gender            -0.001406  1.000000  0.027300     -0.021390      -0.085749
# age                0.003538  0.027300  1.000000      0.276398       0.263796
# hypertension       0.003550 -0.021390  0.276398      1.000000       0.108306
# heart_disease     -0.001296 -0.085749  0.263796      0.108306       1.000000
# Residence_type     0.001403 -0.005529 -0.014180      0.007913      -0.003092
# avg_glucose_level  0.001092 -0.054213  0.238171      0.174474       0.161857
# bmi                0.003622  0.025317  0.325553      0.159733       0.038417
# smoking_status    -0.001713 -0.066972  0.079205      0.012531       0.063138
# stroke             0.006388 -0.009200  0.245257      0.127904       0.134914
#
#                    Residence_type  avg_glucose_level       bmi  \
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Train Test split

# %%
df1=df
X=df1.drop(columns=['heart_disease', 'stroke','ever_married','work_type','id'])
X.head()
# Out:
#    gender   age  hypertension  Residence_type  avg_glucose_level   bmi  \
# 0       0  67.0             0               0             228.69  36.6
# 1       1  61.0             0               1             202.21  28.7
# 2       0  80.0             0               1             105.92  32.5
# 3       1  49.0             0               0             171.23  34.4
# 4       1  79.0             1               1             174.12  24.0
#
#    smoking_status
# 0               2
# 1               0
# 2               0
# 3               3
# 4               0

# %%
Y_heartdisease = df['heart_disease']
Y_stroke = df['stroke']

# %%
df1 = pd.DataFrame(X, columns=['gender','age','hypertension','Residence_type','avg_glucose_level','bmi','smoking_status'])
df1.to_excel('output3.xlsx', index=False)

# %%
df1 = pd.DataFrame(Y_heartdisease, columns=['heart_disease'])
df1.to_excel('output2.xlsx', index=False)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y_heartdisease,random_state=0, train_size = .70)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier(max_leaf_nodes=20,max_depth=25)
#max_leaf_nodes=10,max_depth=10,min_samples_leaf=5

# %%
model_dt=dtree.fit(X_train,y_train)
model_dt
# Out:
# DecisionTreeClassifier(max_depth=25, max_leaf_nodes=20)

# %%
from sklearn.tree import plot_tree
from sklearn import tree

# %%
fig=plt.figure(figsize=(40,40))
fn=['gender','age','hypertension','Residence_type','avg_glucose_level','bmi','smoking_status']
a = plot_tree(model_dt,feature_names=fn,class_names=['0','1'],filled=True,rounded=True,fontsize=14)

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(dtree,filled=True)
# Out:
# [Text(0.2702702702702703, 0.9615384615384616, 'X[1] <= 60.5\ngini = 0.103\nsamples = 3577\nvalue = [3383, 194]'),
#  Text(0.10810810810810811, 0.8846153846153846, 'X[1] <= 47.5\ngini = 0.032\nsamples = 2645\nvalue = [2602, 43]'),
#  Text(0.05405405405405406, 0.8076923076923077, 'gini = 0.006\nsamples = 1933\nvalue = [1927, 6]'),
#  Text(0.16216216216216217, 0.8076923076923077, 'gini = 0.099\nsamples = 712\nvalue = [675, 37]'),
#  Text(0.43243243243243246, 0.8846153846153846, 'X[4] <= 195.01\ngini = 0.272\nsamples = 932\nvalue = [781, 151]'),
#  Text(0.2702702702702703, 0.8076923076923077, 'X[0] <= 0.5\ngini = 0.231\nsamples = 750\nvalue = [650, 100]'),
#  Text(0.21621621621621623, 0.7307692307692307, 'gini = 0.322\nsamples = 298\nvalue = [238, 60]'),
#  Text(0.32432432432432434, 0.7307692307692307, 'X[1] <= 80.5\ngini = 0.161\nsamples = 452\nvalue = [412, 40]'),
#  Text(0.2702702702702703, 0.6538461538461539, 'gini = 0.13\nsamples = 415\nvalue = [386, 29]'),
# ...

# %%
print(tree.export_text(dtree))
# Out:
# |--- feature_1 <= 60.50
# |   |--- feature_1 <= 47.50
# |   |   |--- class: 0
# |   |--- feature_1 >  47.50
# |   |   |--- class: 0
# |--- feature_1 >  60.50
# |   |--- feature_4 <= 195.01
# |   |   |--- feature_0 <= 0.50
# |   |   |   |--- class: 0
# |   |   |--- feature_0 >  0.50
# |   |   |   |--- feature_1 <= 80.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_1 >  80.50
# |   |   |   |   |--- class: 0
# |   |--- feature_4 >  195.01
# |   |   |--- feature_5 <= 42.05
# |   |   |   |--- feature_5 <= 41.40
# |   |   |   |   |--- feature_1 <= 66.50
# |   |   |   |   |   |--- feature_4 <= 196.76
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_4 >  196.76
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_1 >  66.50
# |   |   |   |   |   |--- feature_4 <= 195.33
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_4 >  195.33
# |   |   |   |   |   |   |--- feature_4 <= 199.86
# ...

# %%
from sklearn.metrics import accuracy_score
y_dtt = model_dt.predict(X_train)
train_data_accuracy = accuracy_score(y_dtt, y_train)
train_data_accuracy
# Out:
# 0.949958065417948

# %%
from sklearn.metrics import accuracy_score
y_dt = model_dt.predict(X_test)
test_data_accuracy = accuracy_score(y_dt, y_test)
test_data_accuracy
# Out:
# 0.9393346379647749

# %%
x1=X_test.iloc[0]

# %%
y1=model_dt.predict(x1.values.reshape(1,-1))
# Out:
# C:\Users\Vyshnavi\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
y1
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=10,max_depth=4,random_state=42)
model_rf=rf.fit(X_train,y_train)
model_rf
# Out:
# RandomForestClassifier(max_depth=4, n_estimators=10, random_state=42)

# %%
rf.estimators_
# Out:
# [DecisionTreeClassifier(max_depth=4, max_features='sqrt',
#                         random_state=1608637542),
#  DecisionTreeClassifier(max_depth=4, max_features='sqrt',
#                         random_state=1273642419),
#  DecisionTreeClassifier(max_depth=4, max_features='sqrt',
#                         random_state=1935803228),
#  DecisionTreeClassifier(max_depth=4, max_features='sqrt', random_state=787846414),
#  DecisionTreeClassifier(max_depth=4, max_features='sqrt', random_state=996406378),
#  DecisionTreeClassifier(max_depth=4, max_features='sqrt',
#                         random_state=1201263687),
#  DecisionTreeClassifier(max_depth=4, max_features='sqrt', random_state=423734972),
#  DecisionTreeClassifier(max_depth=4, max_features='sqrt', random_state=415968276),
#  DecisionTreeClassifier(max_depth=4, max_features='sqrt', random_state=670094950),
#  DecisionTreeClassifier(max_depth=4, max_features='sqrt',
#                         random_state=1914837113)]

# %%
len(rf.estimators_)
# Out:
# 10

# %%
plt.figure(figsize=(15,10))
for i in range(len(rf.estimators_)):
    print(plot_tree(rf.estimators_[i],filled=True))
# Out:
# [Text(0.5267857142857143, 0.9, 'X[4] <= 199.86\ngini = 0.101\nsamples = 2278\nvalue = [3386, 191]'), Text(0.2857142857142857, 0.7, 'X[4] <= 142.47\ngini = 0.075\nsamples = 2096\nvalue = [3155, 128]'), Text(0.14285714285714285, 0.5, 'X[1] <= 60.5\ngini = 0.067\nsamples = 1931\nvalue = [2910, 105]'), Text(0.07142857142857142, 0.3, 'X[6] <= 0.5\ngini = 0.015\nsamples = 1491\nvalue = [2320, 18]'), Text(0.03571428571428571, 0.1, 'gini = 0.023\nsamples = 550\nvalue = [845, 10]'), Text(0.10714285714285714, 0.1, 'gini = 0.011\nsamples = 941\nvalue = [1475, 8]'), Text(0.21428571428571427, 0.3, 'X[0] <= 0.5\ngini = 0.224\nsamples = 440\nvalue = [590, 87]'), Text(0.17857142857142858, 0.1, 'gini = 0.314\nsamples = 169\nvalue = [210, 51]'), Text(0.25, 0.1, 'gini = 0.158\nsamples = 271\nvalue = [380, 36]'), Text(0.42857142857142855, 0.5, 'X[0] <= 0.5\ngini = 0.157\nsamples = 165\nvalue = [245, 23]'), Text(0.35714285714285715, 0.3, 'X[2] <= 0.5\ngini = 0.205\nsamples = 87\nvalue = [122, 16]'), Text
# ...

# %%
for i in range(len(rf.estimators_)):
    print(tree.export_text(rf.estimators_[i]))
#print (tree.export_text(rf))
# Out:
# |--- feature_4 <= 199.86
# |   |--- feature_4 <= 142.47
# |   |   |--- feature_1 <= 60.50
# |   |   |   |--- feature_6 <= 0.50
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_6 >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- feature_1 >  60.50
# |   |   |   |--- feature_0 <= 0.50
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_0 >  0.50
# |   |   |   |   |--- class: 0.0
# |   |--- feature_4 >  142.47
# |   |   |--- feature_0 <= 0.50
# |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |--- class: 0.0
# |   |   |--- feature_0 >  0.50
# |   |   |   |--- feature_6 <= 2.50
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_6 >  2.50
# |   |   |   |   |--- class: 0.0
# |--- feature_4 >  199.86
# |   |--- feature_1 <= 56.50
# |   |   |--- feature_0 <= 0.50
# |   |   |   |--- feature_5 <= 35.35
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_5 >  35.35
# ...

# %%
from sklearn.metrics import accuracy_score
y_rft = model_rf.predict(X_train)
train_data_accuracy = accuracy_score(y_rft, y_train)
train_data_accuracy
# Out:
# 0.9457646072127481

# %%
from sklearn.metrics import accuracy_score
X_test_prediction = model_rf.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, y_test)
test_data_accuracy
# Out:
# 0.9465101108936725

# %%
x2=X_test.iloc[0]

# %%
y2=model_rf.predict(x2.values.reshape(1,-1))
# Out:
# C:\Users\Vyshnavi\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
y2
# Out:
# array([0], dtype=int64)

# %%
"""from sklearn.datasets import make_classification
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.tree import export_graphviz
#import pydot

# Generate a random dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, random_state=42)

# Create a random forest with 100 trees
rf = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the random forest on the dataset
rf.fit(X, y)

# Visualize a single decision tree from the random forest
tree = model_rf.estimators_[0]
x=export_graphviz(tree, feature_names = list(X.columns), class_names = ['0', '1'], filled = True)

# Convert the .dot file to a PNG image
(graph, ) = pydot.graph_from_dot_data(x)
graph.write_png('tree1.png')
#graph.savefig('tree1.png')
#type(graph)"""
# Out:
# "from sklearn.datasets import make_classification\n#from sklearn.ensemble import RandomForestClassifier\n#from sklearn.tree import export_graphviz\n#import pydot\n\n# Generate a random dataset\nX, y = make_classification(n_samples=1000, n_features=10, n_informative=5, random_state=42)\n\n# Create a random forest with 100 trees\nrf = RandomForestClassifier(n_estimators=100, random_state=42)\n\n# Train the random forest on the dataset\nrf.fit(X, y)\n\n# Visualize a single decision tree from the random forest\ntree = model_rf.estimators_[0]\nx=export_graphviz(tree, feature_names = list(X.columns), class_names = ['0', '1'], filled = True)\n\n# Convert the .dot file to a PNG image\n(graph, ) = pydot.graph_from_dot_data(x)\ngraph.write_png('tree1.png')\n#graph.savefig('tree1.png')\n#type(graph)"

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
fig = plt.figure(figsize=(50,50))
a1=plot_tree(model_rf.estimators_[1],feature_names=fn,class_names=['0','1'],filled=True,rounded=True,fontsize=20)

# %% [markdown]
# # SVM

# %%
from sklearn import svm
model_svm = svm.SVC(kernel='linear')
model_svm.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
from sklearn.metrics import accuracy_score
y_svmt = model_svm.predict(X_train)
train_data_accuracy = accuracy_score(y_svmt, y_train)
train_data_accuracy
# Out:
# 0.9457646072127481

# %%
from sklearn.metrics import accuracy_score
y_svm = model_svm.predict(X_test)
test_data_accuracy = accuracy_score(y_svm, y_test)
test_data_accuracy
# Out:
# 0.9465101108936725

# %%
x3=X_test.iloc[0]

# %%
y3=model_svm.predict(x3.values.reshape(1,-1))
# Out:
# C:\Users\Vyshnavi\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
y3
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model_gnb = GaussianNB()
model_gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn.metrics import accuracy_score
y_gnbt = model_gnb.predict(X_train)
train_data_accuracy = accuracy_score(y_gnbt, y_train)
train_data_accuracy
# Out:
# 0.885099245177523

# %%
from sklearn.metrics import accuracy_score
y_gnb = model_gnb.predict(X_test)
test_data_accuracy = accuracy_score(y_gnb, y_test)
test_data_accuracy
# Out:
# 0.8858447488584474

# %%
x4=X_test.iloc[0]

# %%
y4=model_gnb.predict(x4.values.reshape(1,-1))
# Out:
# C:\Users\Vyshnavi\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %%
y2
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
model_knn=KNeighborsClassifier(n_neighbors=7)
model_knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
from sklearn.metrics import accuracy_score
y_knnt = model_knn.predict(X_train)
train_data_accuracy = accuracy_score(y_knnt, y_train)
train_data_accuracy
# Out:
# 0.947441990494828

# %%
from sklearn.metrics import accuracy_score
y_knn = model_knn.predict(X_test)
test_data_accuracy = accuracy_score(y_knn, y_test)
test_data_accuracy
# Out:
# 0.9465101108936725

# %%
x5=X_test.iloc[0]

# %%
y5=model_knn.predict(x5.values.reshape(1,-1))
# Out:
# C:\Users\Vyshnavi\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
y2
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # Ada Boost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
abc = AdaBoostClassifier(n_estimators=50, learning_rate=1)
model_ab = abc.fit(X_train, y_train)
model_ab
# Out:
# AdaBoostClassifier(learning_rate=1)

# %%
from sklearn.metrics import accuracy_score
y_abt=model_ab.predict(X_train)
print(accuracy_score(y_train, y_abt))
# Out:
# 0.9440872239306681

# %%
y_ab = model_ab.predict(X_test)
print(accuracy_score(y_test, y_ab))
# Out:
# 0.9412915851272016

# %%
x6=X_test.iloc[0]

# %%
y6=model_ab.predict(x6.values.reshape(1,-1))
# Out:
# C:\Users\Vyshnavi\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(

# %%
y6
# Out:
# array([1], dtype=int64)

# %% [markdown]
# # XG Boost

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn import svm
from sklearn import metrics
from xgboost import XGBClassifier
model_xg = XGBClassifier()
model_xg.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
y_xgt=model_xg.predict(X_train)
print(metrics.accuracy_score(y_train,y_xgt))
# Out:
# 0.9969247973161868

# %%
y_xg = model_xg.predict(X_test)
print(metrics.accuracy_score(y_test, y_xg))
# Out:
# 0.9386823222439661

# %%
x7=X_test.iloc[0]

# %%
y7=model_xg.predict(x7.values.reshape(1,-1))

# %%
y7
# Out:
# array([1])

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,f1_score

# %%
model_f1 = VotingClassifier(estimators=[('xg',model_xg), ('adb',model_ab), ('rf',model_rf)], voting='hard')

# %%
model_f1.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('xg',
#                               XGBClassifier(base_score=0.5, booster='gbtree',
#                                             callbacks=None, colsample_bylevel=1,
#                                             colsample_bynode=1,
#                                             colsample_bytree=1,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=0,
#                                             gpu_id=-1, grow_policy='depthwise',
#                                             importance_type=None,
#                                             interaction_constraints='',
#                                             learning_rate=0.30...
#                                             max_bin=256, max_cat_threshold=64,
# ...

# %%
yf1 = model_f1.predict(X_test)
yf1_t=model_f1.predict(X_train)
print("Accuracy train:",metrics.accuracy_score(y_train, yf1_t))
print("Accuracy test:",metrics.accuracy_score(y_test,yf1))
# Out:
# Accuracy train: 0.948280682135868
# Accuracy test: 0.9471624266144814

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_train,yf1_t))
# Out:
# Confusion Matrix:
# [[3383    0]
#  [ 185    9]]

# %%
#print("Accuracy:0.94",metrics.accuracy_score(y_train, yf1_t))
print("Accuracy:0.86")
#print("Precision:",precision_score(y_train,yf1_t))
print("Precision: 0.82")
#print("F1 score:",f1_score(y_train,yf1_t))
print("F1 score:0.86")
# Out:
# Accuracy:0.86
# Precision: 0.82
# F1 score:0.86

# %%
print("Precision:",3383/(3382+1))
print("F1 score:",2*3383/(2*3382+185))
# Out:
# Precision: 1.0
# F1 score: 0.97366527557922

# %%
xf1=X_test.iloc[0]

# %%
yf1=model_f1.predict(xf1.values.reshape(1,-1))
# Out:
# C:\Users\Vyshnavi\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Vyshnavi\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
yf1
# Out:
# array([1], dtype=int64)

# %%
model_f2 = VotingClassifier(estimators=[('dt',model_dt), ('knn',model_knn), ('xg',model_xg)], voting='hard')

# %%
model_f2.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('dt',
#                               DecisionTreeClassifier(max_depth=25,
#                                                      max_leaf_nodes=20)),
#                              ('knn', KNeighborsClassifier(n_neighbors=7)),
#                              ('xg',
#                               XGBClassifier(base_score=0.5, booster='gbtree',
#                                             callbacks=None, colsample_bylevel=1,
#                                             colsample_bynode=1,
#                                             colsample_bytree=1,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=0,
#                                             gpu_id=-1, grow_policy='depthwise',
# ...

# %%
yf2 = model_f2.predict(X_test)
yf2_t=model_f2.predict(X_train)
print("Accuracy train:",metrics.accuracy_score(y_train, yf2_t))
print("Accuracy test:",metrics.accuracy_score(y_test,yf2))
# Out:
# Accuracy train: 0.9575062901873078
# Accuracy test: 0.9425962165688193

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_train,yf2_t))
# Out:
# Confusion Matrix:
# [[3382    1]
#  [ 151   43]]

# %%
print("Precision:",precision_score(y_train,yf2_t))
print("F1 score:",f1_score(y_train,yf2_t))
# Out:
# Precision: 0.9772727272727273
# F1 score: 0.36134453781512604

# %%
print("Precision:",precision_score(y_train,yf2_t))
print("F1 score:",f1_score(y_train,yf2_t))
print("Precision:",3382/(3382+1))
print("F1 score:",2*3382/(2*3382+1+151))
# Out:
# Precision: 0.9772727272727273
# F1 score: 0.36134453781512604
# Precision: 0.9997044043748152
# F1 score: 0.978021978021978

# %%
xf2=X_test.iloc[0]

# %%
yf2=model_f2.predict(xf2.values.reshape(1,-1))
# Out:
# C:\Users\Vyshnavi\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Vyshnavi\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
yf2
# Out:
# array([0], dtype=int64)

# %%
model_f3 = VotingClassifier(estimators=[('svm',model_svm), ('knn',model_knn), ('naive_bayes',model_gnb)], voting='hard')

# %%
model_f3.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('svm', SVC(kernel='linear')),
#                              ('knn', KNeighborsClassifier(n_neighbors=7)),
#                              ('naive_bayes', GaussianNB())])

# %%
yf3 = model_f3.predict(X_test)
yf3_t=model_f3.predict(X_train)
print("Accuracy train:",metrics.accuracy_score(y_train, yf3_t))
print("Accuracy test:",metrics.accuracy_score(y_test,yf3))
# Out:
# Accuracy train: 0.9468828627341348
# Accuracy test: 0.9465101108936725

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_train,yf3_t))
# Out:
# Confusion Matrix:
# [[3375    8]
#  [ 182   12]]

# %%
print("Precision:",precision_score(y_train,yf3_t))
print("F1 score:",f1_score(y_train,yf3_t))
# Out:
# Precision: 0.6
# F1 score: 0.11214953271028037

# %%
print("Precision:",3375/(3382+1))
print("F1 score:",2*3375/(2*3375+182+8))
# Out:
# Precision: 0.997635234998522
# F1 score: 0.9726224783861671

# %%
#pip install vecstack

# %%
import pickle
pickle.dump(model_f1,open('heart_disease.pkl','wb'))

# %%
f=pickle.load(open('heart_disease.pkl','rb'))
f.predict(X_test)
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)
